# %%
library("r2d2")

# %%
df <- read.table("EoS-insensitive_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["r1"])))
y = as.numeric(unlist(c(df["m1"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionR", "ConfRegionM")
write.csv(wdf, "GW170817_EoS_insensitive_mr90conf_1.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1    lambda2   r1        r2
# 1    1.543236 1.205749  97.068200  248.5412 10.730811  9.358211
# 2    1.482590 1.253115  19.677667  280.4810  8.186003  9.833989
# 3    1.541613 1.206940  31.524739  235.5115  9.149591  9.373914
# 4    1.562878 1.191476  49.572338  409.6818  9.951128 10.102846
# 5    1.656298 1.128266  27.441288  246.9301  9.602853  9.395534
# 6    1.587290 1.174319  84.824304  455.6847 10.672718 10.204561
# 7    1.515999 1.226523  88.591520  387.9071 10.344514 10.276095
# 8    1.494183 1.243641 130.016899  298.5335 11.336830  9.806641
# 9    1.601522 1.164412 107.787088  734.1348 11.731850 10.727742
# 10   1.370549 1.353682 196.504429  217.9254 10.564993 10.466460
# 11   1.629570 1.145844 146.334172 1545.8760 12.302084 12.316750
# 12   1.624554 1.148994  61.217013  746.2744 10.408661 11.154821
# 13   1.420814 1.306448 597.031983  984.2246 13.132928 12.549854
# 14   1.484507 1.251530 119.416438  318.3407 10.435429 10.235428
# ...

# %%
df <- read.table("EoS-insensitive_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["r2"])))
y = as.numeric(unlist(c(df["m2"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionR", "ConfRegionM")
write.csv(wdf, "GW170817_EoS_insensitive_mr90conf_2.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1    lambda2   r1        r2
# 1    1.543236 1.205749  97.068200  248.5412 10.730811  9.358211
# 2    1.482590 1.253115  19.677667  280.4810  8.186003  9.833989
# 3    1.541613 1.206940  31.524739  235.5115  9.149591  9.373914
# 4    1.562878 1.191476  49.572338  409.6818  9.951128 10.102846
# 5    1.656298 1.128266  27.441288  246.9301  9.602853  9.395534
# 6    1.587290 1.174319  84.824304  455.6847 10.672718 10.204561
# 7    1.515999 1.226523  88.591520  387.9071 10.344514 10.276095
# 8    1.494183 1.243641 130.016899  298.5335 11.336830  9.806641
# 9    1.601522 1.164412 107.787088  734.1348 11.731850 10.727742
# 10   1.370549 1.353682 196.504429  217.9254 10.564993 10.466460
# 11   1.629570 1.145844 146.334172 1545.8760 12.302084 12.316750
# 12   1.624554 1.148994  61.217013  746.2744 10.408661 11.154821
# 13   1.420814 1.306448 597.031983  984.2246 13.132928 12.549854
# 14   1.484507 1.251530 119.416438  318.3407 10.435429 10.235428
# ...

# %%
df <- read.table("EoS-insensitive_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["m1"])))
y = as.numeric(unlist(c(df["lambda1"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionM", "ConfRegionLambda")
write.csv(wdf, "GW170817_EoS_insensitive_mlambda90conf_1.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1    lambda2   r1        r2
# 1    1.543236 1.205749  97.068200  248.5412 10.730811  9.358211
# 2    1.482590 1.253115  19.677667  280.4810  8.186003  9.833989
# 3    1.541613 1.206940  31.524739  235.5115  9.149591  9.373914
# 4    1.562878 1.191476  49.572338  409.6818  9.951128 10.102846
# 5    1.656298 1.128266  27.441288  246.9301  9.602853  9.395534
# 6    1.587290 1.174319  84.824304  455.6847 10.672718 10.204561
# 7    1.515999 1.226523  88.591520  387.9071 10.344514 10.276095
# 8    1.494183 1.243641 130.016899  298.5335 11.336830  9.806641
# 9    1.601522 1.164412 107.787088  734.1348 11.731850 10.727742
# 10   1.370549 1.353682 196.504429  217.9254 10.564993 10.466460
# 11   1.629570 1.145844 146.334172 1545.8760 12.302084 12.316750
# 12   1.624554 1.148994  61.217013  746.2744 10.408661 11.154821
# 13   1.420814 1.306448 597.031983  984.2246 13.132928 12.549854
# 14   1.484507 1.251530 119.416438  318.3407 10.435429 10.235428
# ...

# %%
df <- read.table("EoS-insensitive_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["m2"])))
y = as.numeric(unlist(c(df["lambda2"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=19)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionM", "ConfRegionLambda")
write.csv(wdf, "GW170817_EoS_insensitive_mlambda90conf_2.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1    lambda2   r1        r2
# 1    1.543236 1.205749  97.068200  248.5412 10.730811  9.358211
# 2    1.482590 1.253115  19.677667  280.4810  8.186003  9.833989
# 3    1.541613 1.206940  31.524739  235.5115  9.149591  9.373914
# 4    1.562878 1.191476  49.572338  409.6818  9.951128 10.102846
# 5    1.656298 1.128266  27.441288  246.9301  9.602853  9.395534
# 6    1.587290 1.174319  84.824304  455.6847 10.672718 10.204561
# 7    1.515999 1.226523  88.591520  387.9071 10.344514 10.276095
# 8    1.494183 1.243641 130.016899  298.5335 11.336830  9.806641
# 9    1.601522 1.164412 107.787088  734.1348 11.731850 10.727742
# 10   1.370549 1.353682 196.504429  217.9254 10.564993 10.466460
# 11   1.629570 1.145844 146.334172 1545.8760 12.302084 12.316750
# 12   1.624554 1.148994  61.217013  746.2744 10.408661 11.154821
# 13   1.420814 1.306448 597.031983  984.2246 13.132928 12.549854
# 14   1.484507 1.251530 119.416438  318.3407 10.435429 10.235428
# ...

# %%
df <- read.table("Parametrized-EoS_maxmass_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["r1"])))
y = as.numeric(unlist(c(df["m1"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionR", "ConfRegionM")
write.csv(wdf, "GW170817_EoS_parametrized_mr90conf_1.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1   lambda2   r1       r2
# 1    1.637296 1.140765  66.37387  723.5231 10.88739 11.09735
# 2    1.612825 1.156845 191.20730 1335.3399 12.40206 12.34925
# 3    1.563015 1.191614 200.52655 1156.2728 12.28545 12.50122
# 4    1.625307 1.148567 134.83312 1439.5974 12.14149 12.62727
# 5    1.625909 1.148243 177.09947 1428.2817 12.39969 12.42615
# 6    1.566764 1.188887 140.24625  757.2887 11.51648 11.51983
# 7    1.625345 1.148525  71.42686  647.7065 10.82930 10.87819
# 8    1.574682 1.183239 234.82368 1378.4156 12.60475 12.72499
# 9    1.557294 1.195653  93.41937  518.4654 10.80916 10.88877
# 10   1.592426 1.170829 115.15432  788.6510 11.41233 11.48237
# 11   1.500218 1.239024 158.20899  503.8658 11.17712 11.13988
# 12   1.372577 1.351879 664.32753  726.2393 12.92097 12.92031
# 13   1.421835 1.305389 145.06268  248.9552 10.49742 10.49699
# 14   1.509153 1.232037 105.16557  400.0440 10.71490 10.81139
# ...

# %%
df <- read.table("Parametrized-EoS_maxmass_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["r2"])))
y = as.numeric(unlist(c(df["m2"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionR", "ConfRegionM")
write.csv(wdf, "GW170817_EoS_parametrized_mr90conf_2.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1   lambda2   r1       r2
# 1    1.637296 1.140765  66.37387  723.5231 10.88739 11.09735
# 2    1.612825 1.156845 191.20730 1335.3399 12.40206 12.34925
# 3    1.563015 1.191614 200.52655 1156.2728 12.28545 12.50122
# 4    1.625307 1.148567 134.83312 1439.5974 12.14149 12.62727
# 5    1.625909 1.148243 177.09947 1428.2817 12.39969 12.42615
# 6    1.566764 1.188887 140.24625  757.2887 11.51648 11.51983
# 7    1.625345 1.148525  71.42686  647.7065 10.82930 10.87819
# 8    1.574682 1.183239 234.82368 1378.4156 12.60475 12.72499
# 9    1.557294 1.195653  93.41937  518.4654 10.80916 10.88877
# 10   1.592426 1.170829 115.15432  788.6510 11.41233 11.48237
# 11   1.500218 1.239024 158.20899  503.8658 11.17712 11.13988
# 12   1.372577 1.351879 664.32753  726.2393 12.92097 12.92031
# 13   1.421835 1.305389 145.06268  248.9552 10.49742 10.49699
# 14   1.509153 1.232037 105.16557  400.0440 10.71490 10.81139
# ...

# %%
df <- read.table("Parametrized-EoS_maxmass_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["m1"])))
y = as.numeric(unlist(c(df["lambda1"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionM", "ConfRegionLambda")
write.csv(wdf, "GW170817_EoS_insensitive_mlambda90conf_1.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1   lambda2   r1       r2
# 1    1.637296 1.140765  66.37387  723.5231 10.88739 11.09735
# 2    1.612825 1.156845 191.20730 1335.3399 12.40206 12.34925
# 3    1.563015 1.191614 200.52655 1156.2728 12.28545 12.50122
# 4    1.625307 1.148567 134.83312 1439.5974 12.14149 12.62727
# 5    1.625909 1.148243 177.09947 1428.2817 12.39969 12.42615
# 6    1.566764 1.188887 140.24625  757.2887 11.51648 11.51983
# 7    1.625345 1.148525  71.42686  647.7065 10.82930 10.87819
# 8    1.574682 1.183239 234.82368 1378.4156 12.60475 12.72499
# 9    1.557294 1.195653  93.41937  518.4654 10.80916 10.88877
# 10   1.592426 1.170829 115.15432  788.6510 11.41233 11.48237
# 11   1.500218 1.239024 158.20899  503.8658 11.17712 11.13988
# 12   1.372577 1.351879 664.32753  726.2393 12.92097 12.92031
# 13   1.421835 1.305389 145.06268  248.9552 10.49742 10.49699
# 14   1.509153 1.232037 105.16557  400.0440 10.71490 10.81139
# ...

# %%
df <- read.table("Parametrized-EoS_maxmass_posterior_samples.dat", header=FALSE, col.names=c("m1", "m2", "lambda1", "lambda2", "r1", "r2"), skip=1)

df

x = as.numeric(unlist(c(df["m2"])))
y = as.numeric(unlist(c(df["lambda2"])))

plot(x, y)
surf <- MASS::kde2d(x, y, n=300)
region <- conf2d_int(x, y, surf, level=0.90, n=300)
polygon(region, lwd=2)

wdf <- data.frame(region[1], region[2])
colnames(wdf) <- c("ConfRegionM", "ConfRegionLambda")
write.csv(wdf, "GW170817_EoS_insensitive_mlambda90conf_2.csv", row.names=FALSE)
# Out:
#      m1       m2       lambda1   lambda2   r1       r2
# 1    1.637296 1.140765  66.37387  723.5231 10.88739 11.09735
# 2    1.612825 1.156845 191.20730 1335.3399 12.40206 12.34925
# 3    1.563015 1.191614 200.52655 1156.2728 12.28545 12.50122
# 4    1.625307 1.148567 134.83312 1439.5974 12.14149 12.62727
# 5    1.625909 1.148243 177.09947 1428.2817 12.39969 12.42615
# 6    1.566764 1.188887 140.24625  757.2887 11.51648 11.51983
# 7    1.625345 1.148525  71.42686  647.7065 10.82930 10.87819
# 8    1.574682 1.183239 234.82368 1378.4156 12.60475 12.72499
# 9    1.557294 1.195653  93.41937  518.4654 10.80916 10.88877
# 10   1.592426 1.170829 115.15432  788.6510 11.41233 11.48237
# 11   1.500218 1.239024 158.20899  503.8658 11.17712 11.13988
# 12   1.372577 1.351879 664.32753  726.2393 12.92097 12.92031
# 13   1.421835 1.305389 145.06268  248.9552 10.49742 10.49699
# 14   1.509153 1.232037 105.16557  400.0440 10.71490 10.81139
# ...
